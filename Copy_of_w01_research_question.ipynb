# %% [markdown]
# <a href="https://colab.research.google.com/github/dhinesh-66/flyrank-ml-internship/blob/main/Copy_of_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
import os

print("Current directory:", os.getcwd())
print("\nFiles in current directory:")
print(os.listdir())
# Out:
# Current directory: /content/flyrank-ml-internship
#
# Files in current directory:
# ['notebooks', 'work', 'AGENTS.md', 'skills', 'DATA_USE.md', 'Copy_of_01_first_look_and_discovery.ipynb', 'scripts', '.github', 'LICENSE', '.gitignore', 'outputs', 'CLAUDE.md', 'data', 'README.md', 'submission', '.git', 'GUIDE.md', 'SETUP.md', 'requirements.txt', 'docs', 'Copy_of_w01_research_question.ipynb']

# %%
# !git clone https://github.com/dhinesh-66/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 108 (delta 26), reused 80 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (108/108), 1.84 MiB | 1.90 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# /content/flyrank-ml-internship/flyrank-ml-internship

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /content/flyrank-ml-internship/flyrank-ml-internship
# ['notebooks', 'work', 'AGENTS.md', 'skills', 'DATA_USE.md', 'Copy_of_01_first_look_and_discovery.ipynb', 'scripts', '.github', 'LICENSE', '.gitignore', 'outputs', 'CLAUDE.md', 'data', 'README.md', 'submission', '.git', 'GUIDE.md', 'SETUP.md', 'requirements.txt', 'docs', 'Copy_of_w01_research_question.ipynb']

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(df.head())
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# I chose the **Content Refresh Prioritization** lane because websites often contain many pages, making it difficult for content teams to decide which pages should be updated first. My goal is to identify pages that are more likely to be declining so that the SEO or content team can prioritize their efforts. Machine learning can help by combining multiple page metrics to support better decisions than relying on a single rule.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# **Decision:** Which website pages should be prioritized for content refresh?
#
# **Action:** The SEO or content team can review and update the highest-priority pages first.
#
# **Cost of a Wrong Recommendation:**
#
# - A declining page may be missed, resulting in continued traffic loss.
# - Time and effort may be spent updating pages that did not need immediate attention.
#
# Machine learning can support this decision by analyzing multiple page metrics together and producing a ranked list of pages for review.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total Pages:", len(df))
print("Total Columns:", len(df.columns))
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Average Search Volume:", round(df["search_volume"].mean(), 2))

print("\nTrend Direction Counts:")
print(df["trend_direction"].value_counts())
# Out:
# Total Pages: 30000
# Total Columns: 44
# Average CTR: 0.5107
# Average Search Volume: 158.88
#
# Trend Direction Counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
#
# This project provides decision support by identifying patterns associated with declining content performance. It can help prioritize pages for review, but it cannot prove that one factor causes a page to decline. It also cannot predict Google's ranking algorithm. The recommendations are based on observed relationships in the available data and should be used to support, not replace, human judgment.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
